# %% [markdown]
# # Estimando o impacto do coronavírus no mercado brasileiro
#
# O objetivo desse projeto é analisar o impacto gerado pelo pandemia do coronavírus no mercado de ações do Brasil. Para isso usaremos uma biblioteca do python chamada **casualimpact**. A ideia é que a pandemia serve com um tipo de intervenção no mercado e toda intervenção pode gerar ou não impactos significativos após sua aplicação.
#
# Para analisarmos o impacto de uma intervenção devemos, também, gerar um cenário contrafactual, que seria aquilo que teria acontecido caso a intervenção não tivesse ocorrido e, após isso compararmos os resultados antes e depois no tempo.
#
# Nesse projeto iremos usar uma modelagem **ARIMA** para estimarmos um cenário contrafactual. Esse cenário contrafactual serão as previsões geradas por esse modelo ARIMA até a data final dos dados. O modelo será treinado com dados de 2019 e serão geradas previsões para o anos de 2020. Como a metodologia Box-Jenkins (usada na modelagem ARIMA) é um pouco extensa usaremos uma biblioteca de séries temporais no python que gera o modelo automaticamente (**autoARIMA**) apenas com a adição de parâmetros.
#
# Para esse projeto, especificamente, vamos supor que a intervenção foi gerada apenas pela pandemia do coronavírus.
#
# ## O que é o IBOVESPA?
#
# É um índice que mede o desempenho médio das ações mais negociadas, nos últimos meses, na Bolsa de Valores do Brasil (a B3); as ações que compõem esse índice correspondem a 80% das negociações que acontecem na Bolsa de Valores. O índice existe a mais de 50 anos e ao todo e serve como parâmetro de análise do mercado de capitais brasileiro.
#
# ## Sobre os dados
#
# A base de dados apresenta 6 séries temporais: o índice BOVESPA de abertura, o IBOVESPA de alta, o IBOVESPA de baixa, o IBOVESPA de fechamento, o IBOVESPA ajustado e o Volume negociado. Para nossa análise usaremos apenas o IBOVESPA de fechamento.
#
# ## Importando bibliotecas

# %%
#Bibliotecas de análise de dados
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#autoARIMA
from pmdarima.arima import auto_arima

#análise causal
from causalimpact import CausalImpact

# %% [markdown]
# ## Importando os dados

# %%
bolsa=pd.read_csv("^BVSP.csv")

# %% [markdown]
# Visualizando as primeiros linhas do *dataset*.

# %%
bolsa.head()
# Out:
#          Date     Open     High      Low    Close  Adj Close     Volume
# 0  2019-06-10  97828.0  97856.0  96782.0  97467.0    97467.0  3584000.0
# 1  2019-06-11  97467.0  98985.0  97467.0  98960.0    98960.0  4922400.0
# 2  2019-06-12  98960.0  99240.0  97831.0  98321.0    98321.0  4948800.0
# 3  2019-06-13  98321.0  99364.0  98321.0  98774.0    98774.0  5594000.0
# 4  2019-06-14  98776.0  98981.0  97601.0  98040.0    98040.0  9184900.0

# %% [markdown]
# Observando as últimas linhas do *dataset*.

# %%
bolsa.tail()
# Out:
#            Date     Open     High      Low    Close  Adj Close      Volume
# 242  2020-06-01  87395.0  89019.0  86837.0  88620.0    88620.0   9849400.0
# 243  2020-06-02  88622.0  91046.0  88622.0  91046.0    91046.0  11827300.0
# 244  2020-06-03  91048.0  93710.0  91048.0  93002.0    93002.0  15137900.0
# 245  2020-06-04  92993.0  94132.0  92221.0  93829.0    93829.0  11488000.0
# 246  2020-06-05  93839.0  97356.0  93839.0  94637.0    94637.0  13320300.0

# %% [markdown]
# Indexanço os dados pelo tempo.

# %%
dateparse= lambda dates:pd.datetime.strptime(dates,'%Y-%m-%d')
bolsa=pd.read_csv('^BVSP.csv',parse_dates=['Date'],index_col='Date',date_parser=dateparse)
# Out:
# C:\Users\junio\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Antes tínhamos 7 colunas, agora temos 6 colunas indexadas no tempo.

# %%
bolsa.shape
# Out:
# (247, 6)

# %% [markdown]
# visualizando novamente as colunas do *dataset*.

# %%
bolsa.head()
# Out:
#                Open     High      Low    Close  Adj Close     Volume
# Date
# 2019-06-10  97828.0  97856.0  96782.0  97467.0    97467.0  3584000.0
# 2019-06-11  97467.0  98985.0  97467.0  98960.0    98960.0  4922400.0
# 2019-06-12  98960.0  99240.0  97831.0  98321.0    98321.0  4948800.0
# 2019-06-13  98321.0  99364.0  98321.0  98774.0    98774.0  5594000.0
# 2019-06-14  98776.0  98981.0  97601.0  98040.0    98040.0  9184900.0

# %% [markdown]
# Tabela com estatísticas descritiva dos dados.

# %%
bolsa.describe()
# Out:
#                 Open           High            Low          Close  \
# count     246.000000     246.000000     246.000000     246.000000
# mean    99962.227642  101106.487805   98809.390244   99976.276423
# std     13524.927222   12946.573470   14044.902104   13550.059295
# min     63604.000000   67604.000000   61691.000000   63570.000000
# 25%     96643.750000   97879.750000   94343.000000   95085.250000
# 50%    103489.500000  104218.000000  102702.000000  103492.000000
# 75%    108366.000000  108887.250000  107425.000000  108390.000000
# max    119528.000000  119593.000000  118108.000000  119528.000000
#
#            Adj Close        Volume
# count     246.000000  2.460000e+02
# mean    99976.276423  6.789785e+06
# std     13550.059295  3.269044e+06
# min     63570.000000  0.000000e+00
# 25%     95085.250000  4.515425e+06
# 50%    103492.000000  5.487100e+06
# 75%    108390.000000  8.870625e+06
# max    119528.000000  1.675150e+07

# %% [markdown]
# Visualizando se há *missing values*.
#
# Cada séries possui um *missing values*.

# %%
bolsa.isna().sum()
# Out:
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %% [markdown]
# Vamos excluir esses valores faltantes.

# %%
bolsa=bolsa.dropna()

# %% [markdown]
# Plotando gráfico de série temporal para as séries de abertura e de fechamento.

# %%
plt.figure(figsize=(15,6))
bolsa['Open'].plot(color='r')
bolsa['Close'].plot(color='g')
plt.xlabel('')
plt.title('Índice BOVESPA (Abertura e Fechamento)',size=15)
plt.legend()
plt.show()

#podemos ver nitidamente a queda no ano de 2020

# %% [markdown]
# Plotando gráfico de série de tempo de alta e baixa.

# %%
plt.figure(figsize=(15,6))
bolsa['High'].plot()
bolsa['Low'].plot()
plt.xlabel('')
plt.title('Índice BOVESPA (Alta e Baixa)',size=15)
plt.legend()
plt.show()

# %% [markdown]
# Plotando o gráfico com o volume de ações.

# %%
plt.figure(figsize=(15,6))
plt.plot(bolsa['Volume'])
plt.xlabel('')
plt.title('Índice BOVESPA (Volume)',size=15)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# vamos criar 6 gráficos (3 linhas e 2 colunas) com as séries temporais.
#
# Abaixo podemos ver as séries de abertura, alta, baixa, fechamento, ajustamento e volume. Com exceção da séries de volume, as outras são muito semelhantes.

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, dpi=120, figsize=(10,6))
for i, ax in enumerate(axes.flatten()):
    data = bolsa[bolsa.columns[i]]
    ax.plot(data, color='red', linewidth=1)
    ax.set_title(bolsa.columns[i])
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')
    ax.spines["top"].set_alpha(0)
    ax.tick_params(labelsize=6)

plt.tight_layout();

# %% [markdown]
# ## Estimando um cenário contrafactual
#
# Como já falado anteriormente, iremos utilizar um modelo ARIMA (autorregressivo integrado com médias móveis) para gerarmos um cenário contrafactual. Novamente, um cenário contrafactual é um cenário que ocorreria caso não houve uma intervenção na variável de estudo, que no nosso caso é o índice BOVESPA. Esse cenário estaria sob uma condição *ceteris paribus* (tudo mais constante), isto é, consideramos que as condições de mercado não se alteram.
#
# O modelo ARIMA gerará previsões que servirão como o cenário contrafactual. O autoARIMA irá fazer toda a metodologia Box-Jenkins.
#
# Para a escolha da variável, vamos escolher a variável de fechamento do índice BOVESPA que é o resultado final do índice no final do dia.

# %%
data=bolsa['Close']

# %% [markdown]
# Vamos agora aplicar a modelagem autoARIMA
#
# Esse tipo de modelagem irá treinar várias combinações e gerará vários modelos ARIMA e para esse modelo irei aplicar os parâmetros de start (p,q), de max(p,q) e de diferenciação e diferenciação sazonal.
#
# Abaixo podemos ver os modelos gerados.

# %%
stepwise=auto_arima(data,start_p=1,start_q=1,max_p=6,max_q=6,m=12,start_P=0,seasonal=True,d=1,D=1,trace=True,
                    error_action='ignore',suppress_warnings=True,stepwise=False)
# Out:
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=True]; AIC=4437.985, BIC=4444.887, Time=1.077 seconds
# Fit ARIMA(0,1,0)x(0,1,1,12) [intercept=True]; AIC=4422.655, BIC=4433.008, Time=0.402 seconds
# Fit ARIMA(0,1,0)x(0,1,2,12) [intercept=True]; AIC=4408.446, BIC=4422.250, Time=0.904 seconds
# Fit ARIMA(0,1,0)x(1,1,0,12) [intercept=True]; AIC=4426.955, BIC=4437.308, Time=0.268 seconds
# Fit ARIMA(0,1,0)x(1,1,1,12) [intercept=True]; AIC=4395.989, BIC=4409.794, Time=1.049 seconds
# Fit ARIMA(0,1,0)x(1,1,2,12) [intercept=True]; AIC=4405.096, BIC=4422.351, Time=0.960 seconds
# Fit ARIMA(0,1,0)x(2,1,0,12) [intercept=True]; AIC=4418.366, BIC=4432.170, Time=0.408 seconds
# Fit ARIMA(0,1,0)x(2,1,1,12) [intercept=True]; AIC=4401.631, BIC=4418.886, Time=1.749 seconds
# Fit ARIMA(0,1,0)x(2,1,2,12) [intercept=True]; AIC=4406.307, BIC=4427.014, Time=3.071 seconds
# Fit ARIMA(0,1,1)x(0,1,0,12) [intercept=True]; AIC=4439.181, BIC=4449.535, Time=0.059 seconds
# Fit ARIMA(0,1,1)x(0,1,1,12) [intercept=True]; AIC=4423.606, BIC=4437.411, Time=0.285 seconds
# Fit ARIMA(0,1,1)x(0,1,2,12) [intercept=True]; AIC=4409.801, BIC=4427.056, Time=1.559 seconds
# Fit ARIMA(0,1,1)x(1,1,0,12) [intercept=True]; AIC=4427.911, BIC=4441.715, Time=0.179 seconds
# Fit ARIMA(0,1,1)x(1,1,1,12) [intercept=True]; AIC=4397.187, BIC=4414.442, Time=1.342 seconds
# Fit ARIMA(0,1,1)x(1,1,2,12) [intercept=True]; AIC=4407.185, BIC=4427.891, Time=1.482 seconds
# Fit ARIMA(0,1,1)x(2,1,0,12) [intercept=True]; AIC=4419.367, BIC=4436.622, Time=0.632 seconds
# Fit ARIMA(0,1,1)x(2,1,1,12) [intercept=True]; AIC=4407.329, BIC=4428.035, Time=1.113 seconds
# Fit ARIMA(0,1,1)x(2,1,2,12) [intercept=True]; AIC=4407.973, BIC=4432.130, Time=3.534 seconds
# Fit ARIMA(0,1,2)x(0,1,0,12) [intercept=True]; AIC=4441.169, BIC=4454.974, Time=0.069 seconds
# Fit ARIMA(0,1,2)x(0,1,1,12) [intercept=True]; AIC=4425.745, BIC=4443.000, Time=0.326 seconds
# Fit ARIMA(0,1,2)x(0,1,2,12) [intercept=True]; AIC=4411.961, BIC=4432.667, Time=1.321 seconds
# Fit ARIMA(0,1,2)x(1,1,0,12) [intercept=True]; AIC=4430.044, BIC=4447.299, Time=0.198 seconds
# Fit ARIMA(0,1,2)x(1,1,1,12) [intercept=True]; AIC=4404.235, BIC=4424.942, Time=1.021 seconds
# Fit ARIMA(0,1,2)x(1,1,2,12) [intercept=True]; AIC=4405.105, BIC=4429.262, Time=3.532 seconds
# Fit ARIMA(0,1,2)x(2,1,0,12) [intercept=True]; AIC=4421.598, BIC=4442.304, Time=1.165 seconds
# Fit ARIMA(0,1,2)x(2,1,1,12) [intercept=True]; AIC=4405.135, BIC=4429.292, Time=3.222 seconds
# Fit ARIMA(0,1,3)x(0,1,0,12) [intercept=True]; AIC=4441.797, BIC=4459.053, Time=0.393 seconds
# Fit ARIMA(0,1,3)x(0,1,1,12) [intercept=True]; AIC=4426.841, BIC=4447.547, Time=0.450 seconds
# Fit ARIMA(0,1,3)x(0,1,2,12) [intercept=True]; AIC=4413.438, BIC=4437.596, Time=1.773 seconds
# Fit ARIMA(0,1,3)x(1,1,0,12) [intercept=True]; AIC=4430.981, BIC=4451.687, Time=0.208 seconds
# Fit ARIMA(0,1,3)x(1,1,1,12) [intercept=True]; AIC=4405.606, BIC=4429.763, Time=1.257 seconds
# Fit ARIMA(0,1,3)x(2,1,0,12) [intercept=True]; AIC=4422.924, BIC=4447.082, Time=0.724 seconds
# Fit ARIMA(0,1,4)x(0,1,0,12) [intercept=True]; AIC=4443.169, BIC=4463.876, Time=0.148 seconds
# Fit ARIMA(0,1,4)x(0,1,1,12) [intercept=True]; AIC=4428.770, BIC=4452.927, Time=0.549 seconds
# Fit ARIMA(0,1,4)x(1,1,0,12) [intercept=True]; AIC=4432.762, BIC=4456.919, Time=0.260 seconds
# Fit ARIMA(0,1,5)x(0,1,0,12) [intercept=True]; AIC=4444.896, BIC=4469.053, Time=0.173 seconds
# Fit ARIMA(1,1,0)x(0,1,0,12) [intercept=True]; AIC=4439.210, BIC=4449.563, Time=0.122 seconds
# Fit ARIMA(1,1,0)x(0,1,1,12) [intercept=True]; AIC=4423.359, BIC=4437.163, Time=0.310 seconds
# Fit ARIMA(1,1,0)x(0,1,2,12) [intercept=True]; AIC=4409.337, BIC=4426.592, Time=1.022 seconds
# Fit ARIMA(1,1,0)x(1,1,0,12) [intercept=True]; AIC=4427.742, BIC=4441.546, Time=0.171 seconds
# Fit ARIMA(1,1,0)x(1,1,1,12) [intercept=True]; AIC=4401.267, BIC=4418.522, Time=0.888 seconds
# Fit ARIMA(1,1,0)x(1,1,2,12) [intercept=True]; AIC=4406.517, BIC=4427.223, Time=1.428 seconds
# Fit ARIMA(1,1,0)x(2,1,0,12) [intercept=True]; AIC=4419.067, BIC=4436.323, Time=0.605 seconds
# Fit ARIMA(1,1,0)x(2,1,1,12) [intercept=True]; AIC=4406.648, BIC=4427.354, Time=1.490 seconds
# Fit ARIMA(1,1,0)x(2,1,2,12) [intercept=True]; AIC=4407.371, BIC=4431.529, Time=3.332 seconds
# Fit ARIMA(1,1,1)x(0,1,0,12) [intercept=True]; AIC=4441.181, BIC=4454.985, Time=0.148 seconds
# Fit ARIMA(1,1,1)x(0,1,1,12) [intercept=True]; AIC=4425.557, BIC=4442.812, Time=0.574 seconds
# Fit ARIMA(1,1,1)x(0,1,2,12) [intercept=True]; AIC=4411.651, BIC=4432.357, Time=1.945 seconds
# Fit ARIMA(1,1,1)x(1,1,0,12) [intercept=True]; AIC=4429.890, BIC=4447.146, Time=0.232 seconds
# Fit ARIMA(1,1,1)x(1,1,1,12) [intercept=True]; AIC=4402.866, BIC=4423.572, Time=2.023 seconds
# Fit ARIMA(1,1,1)x(1,1,2,12) [intercept=True]; AIC=4403.891, BIC=4428.049, Time=4.287 seconds
# Fit ARIMA(1,1,1)x(2,1,0,12) [intercept=True]; AIC=4421.325, BIC=4442.031, Time=0.709 seconds
# Fit ARIMA(1,1,1)x(2,1,1,12) [intercept=True]; AIC=4407.447, BIC=4431.604, Time=2.735 seconds
# Fit ARIMA(1,1,2)x(0,1,0,12) [intercept=True]; AIC=4443.071, BIC=4460.326, Time=0.221 seconds
# Fit ARIMA(1,1,2)x(0,1,1,12) [intercept=True]; AIC=4427.629, BIC=4448.336, Time=0.447 seconds
# Fit ARIMA(1,1,2)x(0,1,2,12) [intercept=True]; AIC=4412.604, BIC=4436.762, Time=2.762 seconds
# Fit ARIMA(1,1,2)x(1,1,0,12) [intercept=True]; AIC=4431.883, BIC=4452.589, Time=0.632 seconds
# Fit ARIMA(1,1,2)x(1,1,1,12) [intercept=True]; AIC=4403.604, BIC=4427.761, Time=1.972 seconds
# Fit ARIMA(1,1,2)x(2,1,0,12) [intercept=True]; AIC=4423.502, BIC=4447.660, Time=1.001 seconds
# Fit ARIMA(1,1,3)x(0,1,0,12) [intercept=True]; AIC=4438.624, BIC=4459.330, Time=0.563 seconds
# Fit ARIMA(1,1,3)x(0,1,1,12) [intercept=True]; AIC=4426.726, BIC=4450.883, Time=1.230 seconds
# Fit ARIMA(1,1,3)x(1,1,0,12) [intercept=True]; AIC=4430.049, BIC=4454.207, Time=0.992 seconds
# Fit ARIMA(1,1,4)x(0,1,0,12) [intercept=True]; AIC=4445.009, BIC=4469.166, Time=0.486 seconds
# Fit ARIMA(2,1,0)x(0,1,0,12) [intercept=True]; AIC=4441.177, BIC=4454.981, Time=0.082 seconds
# Fit ARIMA(2,1,0)x(0,1,1,12) [intercept=True]; AIC=4425.412, BIC=4442.667, Time=0.383 seconds
# Fit ARIMA(2,1,0)x(0,1,2,12) [intercept=True]; AIC=4411.421, BIC=4432.127, Time=1.454 seconds
# Fit ARIMA(2,1,0)x(1,1,0,12) [intercept=True]; AIC=4429.785, BIC=4447.040, Time=0.217 seconds
# Fit ARIMA(2,1,0)x(1,1,1,12) [intercept=True]; AIC=4403.386, BIC=4424.092, Time=1.268 seconds
# Fit ARIMA(2,1,0)x(1,1,2,12) [intercept=True]; AIC=4408.486, BIC=4432.643, Time=1.491 seconds
# Fit ARIMA(2,1,0)x(2,1,0,12) [intercept=True]; AIC=4421.147, BIC=4441.853, Time=0.713 seconds
# Fit ARIMA(2,1,0)x(2,1,1,12) [intercept=True]; AIC=4404.285, BIC=4428.442, Time=3.214 seconds
# Fit ARIMA(2,1,1)x(0,1,0,12) [intercept=True]; AIC=4436.780, BIC=4454.035, Time=0.510 seconds
# Fit ARIMA(2,1,1)x(0,1,1,12) [intercept=True]; AIC=4424.433, BIC=4445.139, Time=1.559 seconds
# Fit ARIMA(2,1,1)x(0,1,2,12) [intercept=True]; AIC=4411.619, BIC=4435.776, Time=2.601 seconds
# Fit ARIMA(2,1,1)x(1,1,0,12) [intercept=True]; AIC=4431.690, BIC=4452.396, Time=0.306 seconds
# Fit ARIMA(2,1,1)x(1,1,1,12) [intercept=True]; AIC=4402.545, BIC=4426.702, Time=1.854 seconds
# Fit ARIMA(2,1,1)x(2,1,0,12) [intercept=True]; AIC=4422.966, BIC=4447.123, Time=0.920 seconds
# Fit ARIMA(2,1,2)x(0,1,0,12) [intercept=True]; AIC=4432.003, BIC=4452.709, Time=0.575 seconds
# Fit ARIMA(2,1,2)x(0,1,1,12) [intercept=True]; AIC=4423.256, BIC=4447.414, Time=1.490 seconds
# Fit ARIMA(2,1,2)x(1,1,0,12) [intercept=True]; AIC=4425.616, BIC=4449.773, Time=1.576 seconds
# Fit ARIMA(2,1,3)x(0,1,0,12) [intercept=True]; AIC=4440.528, BIC=4464.686, Time=0.491 seconds
# Fit ARIMA(3,1,0)x(0,1,0,12) [intercept=True]; AIC=4441.656, BIC=4458.911, Time=0.122 seconds
# Fit ARIMA(3,1,0)x(0,1,1,12) [intercept=True]; AIC=4425.949, BIC=4446.655, Time=0.421 seconds
# Fit ARIMA(3,1,0)x(0,1,2,12) [intercept=True]; AIC=4412.024, BIC=4436.182, Time=1.650 seconds
# Fit ARIMA(3,1,0)x(1,1,0,12) [intercept=True]; AIC=4430.276, BIC=4450.983, Time=0.281 seconds
# Fit ARIMA(3,1,0)x(1,1,1,12) [intercept=True]; AIC=4408.261, BIC=4432.418, Time=0.654 seconds
# Fit ARIMA(3,1,0)x(2,1,0,12) [intercept=True]; AIC=4421.831, BIC=4445.988, Time=0.947 seconds
# Fit ARIMA(3,1,1)x(0,1,0,12) [intercept=True]; AIC=4443.498, BIC=4464.205, Time=0.216 seconds
# Fit ARIMA(3,1,1)x(0,1,1,12) [intercept=True]; AIC=4426.692, BIC=4450.850, Time=1.216 seconds
# Fit ARIMA(3,1,1)x(1,1,0,12) [intercept=True]; AIC=4429.718, BIC=4453.875, Time=1.673 seconds
# Fit ARIMA(3,1,2)x(0,1,0,12) [intercept=True]; AIC=4433.887, BIC=4458.044, Time=0.716 seconds
# Fit ARIMA(4,1,0)x(0,1,0,12) [intercept=True]; AIC=4443.371, BIC=4464.077, Time=0.101 seconds
# Fit ARIMA(4,1,0)x(0,1,1,12) [intercept=True]; AIC=4427.799, BIC=4451.956, Time=0.415 seconds
# Fit ARIMA(4,1,0)x(1,1,0,12) [intercept=True]; AIC=4432.112, BIC=4456.269, Time=0.284 seconds
# Fit ARIMA(4,1,1)x(0,1,0,12) [intercept=True]; AIC=4445.243, BIC=4469.401, Time=0.553 seconds
# Fit ARIMA(5,1,0)x(0,1,0,12) [intercept=True]; AIC=4444.916, BIC=4469.074, Time=0.120 seconds
# Total fit time: 99.325 seconds

# %% [markdown]
# Para a escolha do modelo eu irei usar o critério de informação AIC (também poderia usar o critério BIC, mas geralmente o AIC é um critério melhor) e serão usados os modelos com os menores critérios de informação.
#
# Abaixo podemos ver os critérios AIC e BIC, respectivamente.

# %%
display(stepwise.aic())
display(stepwise.bic())
# Out:
# 4395.989430918671
# 4409.793584732934

# %% [markdown]
# O modelo escolhido pelos critério foi o modelo ARIMA(0,1,0)x(1,1,1,12).
#
# É um modelo sem a ordem autorregressiva e sem a ordem de médias móveis, mas os parâmetros de sazonalidade são P,D e Q estão presentes no modelo, mostra que há presença de sazonalidade nos dados.
#
# OBS: o motivo de escolher o modelo com menor AIC (ou BIC) ,é que usamos o princípio da parcimônia, ou seja, escolher o modelo que reduz os erros, porém é o mais simples.

# %% [markdown]
# ## Treinando o modelo *ARIMA*
#
# Vamos agora usar o modelo e treiná-lo com os dados. Para isso iremos separar os dados entre treino e teste.
#
# ### Dados de treino e de teste
#
# Vamos colocar os dados de treino de junho de 2019 até o final do ano de 2019 e os dados de dados de teste irão do começo de 2020 em diante.

# %%
train=data.loc['2019-06-01':'2019-12-31']
test=data.loc['2020-01-01':]

# %% [markdown]
# Treinando o modelo.

# %%
stepwise.fit(train)
# Out:
# ARIMA(order=(0, 1, 0), seasonal_order=(1, 1, 1, 12), suppress_warnings=True)

# %% [markdown]
# Gerando as previsões (nossa contrafactual) : Ao todo são 106 dias (do início do ano até  fim da série).

# %%
future_forecast=stepwise.predict(n_periods=106)

# %% [markdown]
# Transformando as previsões em *dataframe*.

# %%
future_forecast=pd.DataFrame(future_forecast,index=test.index)

# %% [markdown]
# Vamos agora criar uma nova série, em que concatenaremos os dados de 2019 com as previsões para 2020.

# %%
pd.concat([test,future_forecast],axis=1).head(10)
# Out:
#                Close              0
# Date
# 2020-01-02  118573.0  116262.389405
# 2020-01-03  117707.0  117432.775001
# 2020-01-06  116878.0  117870.344667
# 2020-01-07  116662.0  117266.900292
# 2020-01-08  116247.0  118031.534890
# 2020-01-09  115947.0  119661.719621
# 2020-01-10  115503.0  120460.284884
# 2020-01-13  117325.0  120556.023511
# 2020-01-14  117632.0  121307.520075
# 2020-01-15  116414.0  122579.425853

# %% [markdown]
# Em laranja podemos ver as previsões e em azul os valores reais.

# %%
plt.figure(figsize=(15,5))
plt.plot(pd.concat([test,future_forecast],axis=1))
plt.xlabel('')
plt.title('Previsões X Real',size=15)
plt.show()

# %% [markdown]
# Abaixo as séries completas e podemos perceber que as previsões, de certa forma, fazem sentido. Se nada tivesse ocorrido o índice BOVESPA seguiria em alta no ano de 2020.

# %%
plt.figure(figsize=(15,5))
plt.plot(pd.concat([data,future_forecast],axis=1))
plt.legend('')
plt.xlabel('')
plt.title('Índice BOVESPA previsto x Índice BOVESPA real',size=15)
plt.show()

# %% [markdown]
# Criando uma nova coluna no dataset com os dados de treino.

# %%
bolsa['previsão']=train.append(future_forecast[0])

# %%
#future_forecast

# %% [markdown]
# Visualizando o *dataset* com a nova coluna.

# %%
bolsa.tail()
# Out:
#                Open     High      Low    Close  Adj Close      Volume  \
# Date
# 2020-06-01  87395.0  89019.0  86837.0  88620.0    88620.0   9849400.0
# 2020-06-02  88622.0  91046.0  88622.0  91046.0    91046.0  11827300.0
# 2020-06-03  91048.0  93710.0  91048.0  93002.0    93002.0  15137900.0
# 2020-06-04  92993.0  94132.0  92221.0  93829.0    93829.0  11488000.0
# 2020-06-05  93839.0  97356.0  93839.0  94637.0    94637.0  13320300.0
#
#                  previsão
# Date
# 2020-06-01  178586.721893
# 2020-06-02  179620.049807
# 2020-06-03  180130.635323
# 2020-06-04  181156.269146
# 2020-06-05  182588.871441

# %% [markdown]
# Índice BOVESPA previsto x Índice BOVESPA real (Série Completa).

# %%
plt.figure(figsize=(15,6))
#bolsa['Open'].plot(color='r')
bolsa['Close'].plot(color='g')
bolsa['previsão'].plot()
plt.xlabel('')
plt.title('Índice BOVESPA previsto x Índice BOVESPA real (Série Completa)',size=15)
plt.legend()
plt.show()

# %% [markdown]
# Vamos definir uma variável que irá receber os dados de fechamento e os dados com as previsões.

# %%
impacto = pd.DataFrame({'Close': bolsa['Close'],'Previsão': bolsa['previsão']}, columns=['Close','Previsão'])

# %% [markdown]
# Visualizando as 20 primeiras linhas desse *dataset*.

# %%
impacto.head(20)
# Out:
#                Close  Previsão
# Date
# 2019-06-10   97467.0   97467.0
# 2019-06-11   98960.0   98960.0
# 2019-06-12   98321.0   98321.0
# 2019-06-13   98774.0   98774.0
# 2019-06-14   98040.0   98040.0
# 2019-06-17   97623.0   97623.0
# 2019-06-18   99404.0   99404.0
# 2019-06-19  100303.0  100303.0
# 2019-06-21  102013.0  102013.0
# 2019-06-24  102062.0  102062.0
# 2019-06-25  100093.0  100093.0
# 2019-06-26  100689.0  100689.0
# 2019-06-27  100724.0  100724.0
# 2019-06-28  100967.0  100967.0
# 2019-07-01  101340.0  101340.0
# 2019-07-02  100605.0  100605.0
# 2019-07-03  102043.0  102043.0
# 2019-07-04  103636.0  103636.0
# 2019-07-05  104089.0  104089.0
# 2019-07-08  104530.0  104530.0

# %% [markdown]
# Irei definir agora 2 variáveis : uma do período pré-intervenção (quando não ocorre a pandemia) e uma do período pós intervenção.

# %%
pre_period = ['2019-06-10','2019-12-30']
post_period = ['2020-01-02','2020-06-05']

# %% [markdown]
# ## Aplicando *Causal Impact*
#
# Agora iremos aplicar as ferramentas da biblioteca *causal impact*, comparando o cenário contrafactual com o cenário real.
#
# Aplicando a função *Causal Impact*.

# %%
ci = CausalImpact(impacto, pre_period, post_period)
# Out:
# C:\Users\junio\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\junio\Anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# C:\Users\junio\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# C:\Users\junio\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:583: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %% [markdown]
# Gerando o gráfico de comparação do antes e depois da intervenção (ou da pandemia).

# %%
ci.plot()

# %% [markdown]
# Abaixo podemos ver um relatório gerado por essa biblioteca.

# %%
print(ci.summary())
print(ci.summary(output='report'))
# Out:
# Posterior Inference {Causal Impact}
#                           Average            Cumulative
# Actual                    93766.75           9939275.0
# Prediction (s.d.)         146317.38 (209.21) 15509641.97 (22175.83)
# 95% CI                    [145898.99, 146719.07][15465293.34, 15552220.98]
#
# Absolute effect (s.d.)    -52550.63 (209.21) -5570366.97 (22175.83)
# 95% CI                    [-52952.32, -52132.25][-5612945.98, -5526018.34]
#
# Relative effect (s.d.)    -35.92% (0.14%)    -35.92% (0.14%)
# 95% CI                    [-36.19%, -35.63%] [-36.19%, -35.63%]
#
# Posterior tail-area probability p: 0.0
# Posterior prob. of a causal effect: 100.0%
#
# For more details run the command: print(impact.summary('report'))
# Analysis report {CausalImpact}
#
#
# During the post-intervention period, the response variable had
# an average value of approx. 93766.75. By contrast, in the absence of an
# intervention, we would have expected an average response of 146317.38.
# The 95% interval of this counterfactual prediction is [145898.99, 146719.07].
# Subtracting this prediction from the observed response yields
# an estimate of the causal effect the intervention had on the
# response variable. This effect is -52550.63 with a 95% interval of
# [-52952.32, -52132.25]. For a discussion of the significance of this effect,
# see below.
#
#
# Summing up the individual data points during the post-intervention
# period (which can only sometimes be meaningfully interpreted), the
# response variable had an overall value of 9939275.0.
# By contrast, had the intervention not taken place, we would have expected
# a sum of 15509641.97. The 95% interval of this prediction is [15465293.34, 15552220.98].
#
#
# The above results are given in terms of absolute numbers. In relative
# terms, the response variable showed a decrease of -35.92%. The 95%
# interval of this percentage is [-36.19%, -35.63%].
#
#
# This means that the negative effect observed during the intervention
# period is statistically significant.
# If the experimenter had expected a positive effect, it is recommended
# to double-check whether anomalies in the control variables may have
# caused an overly optimistic expectation of what should have happened
# in the response variable in the absence of the intervention.
#
#
# The probability of obtaining this effect by chance is very small
# (Bayesian one-sided tail-area probability p = 0.0).
# This means the causal effect can be considered statistically
# significant.

# %% [markdown]
# ## Tradução do relatório
#
# Durante o período pós-intervenção, a variável resposta teve um valor médio de aprox. 93766.75. Por outro lado, na ausência de um intervenção (ou da pandemia), teríamos esperado uma resposta média de 146317.38. O intervalo de 95% dessa previsão contrafactual é **[145893.85, 146769.53]**. Subtrair essa previsão da resposta observada produz uma estimativa do efeito causal que a intervenção teve no resposta variável. Esse efeito é **-52550.63** com um intervalo de 95% de
# **[-53002.78, -52127.11]**. Para uma discussão sobre o significado desse efeito, ver abaixo.
#
#
# Resumindo os pontos de dados individuais durante a pós-intervenção período (que às vezes só pode ser interpretado de maneira significativa), A variável de resposta teve um valor geral de **9939275.0**. Por outro lado, se a intervenção não tivesse ocorrido, teríamos esperado uma soma de **15509641.92**. O intervalo de 95% dessa previsão é **[15464748.24, 15557570.17]**.
#
#
# Os resultados acima são dados em termos de números absolutos. Em relação termos, a variável resposta apresentou uma queda de **-35,92%**. A 95% o intervalo dessa porcentagem é de **[-36.22%, -35.63%]**.
#
#
# Isso significa que o efeito negativo observado durante a intervenção período é estatisticamente significativo.Se o experimentador esperava um efeito positivo, é recomendável para verificar se anomalias nas variáveis de controle podem ter
# causodo uma expectativa excessivamente otimista do que deveria ter acontecido na variável resposta na ausência da intervenção.
#
#
# A probabilidade de obter esse efeito por acaso é muito pequena (Probabilidade bayesiana unilateral da área da cauda p = 0,0).
# Isso significa que o efeito causal pode ser considerado **estatisticamente significativo**.
#
# ## Conclusão
#
# Considerando as previsões como contrafactuais e a condição *ceteris paribus* (não considerando atrasos nas reformas políticas brasileiras, um choque do petróleo do começo do ano e as falas recorrentes do presidente da república barsileira - que criaram certas instabilidades políticas) a pandemia causada pelo coronavírus (COVID-19) foi estatisticamente significativa para uma queda de quase 36% no IBOVESPA no anos de 2020.
